# %%
# coding: utf-8
import sys
sys.path.append('..')
from common.np import *
from rnnlm_gen import BetterRnnlmGen
from dataset import ptb


corpus, word_to_id, id_to_word = ptb.load_data('train')
vocab_size = len(word_to_id)
corpus_size = len(corpus)


model = BetterRnnlmGen()
model.load_params('../Ch07_Seq2Seq/BetterRnnlm.pkl')

# start 문자와 skip 문자 설정
start_word = 'you'
start_id = word_to_id[start_word]
skip_words = ['N', '<unk>', '$']
skip_ids = [word_to_id[w] for w in skip_words]
# 문장 생성
word_ids = model.generate(start_id, skip_ids)
txt = ' '.join([id_to_word[i] for i in word_ids])
txt = txt.replace(' <eos>', '.\n')

print(txt)


model.reset_state()

start_words = 'the meaning of life is'
start_ids = [word_to_id[w] for w in start_words.split(' ')]

for x in start_ids[:-1]:
    x = np.array(x).reshape(1, 1)
    model.predict(x)

word_ids = model.generate(start_ids[-1], skip_ids)
word_ids = start_ids[:-1] + word_ids
txt = ' '.join([id_to_word[i] for i in word_ids])
txt = txt.replace(' <eos>', '.\n')
print('-' * 50)
print(txt)
# Out:
# | 에폭 1 |  반복 1 / 1327 | 시간 0[s] | 퍼플렉서티 9997.29
# | 에폭 1 |  반복 21 / 1327 | 시간 9[s] | 퍼플렉서티 2695.64
# | 에폭 1 |  반복 41 / 1327 | 시간 18[s] | 퍼플렉서티 1203.62
# | 에폭 1 |  반복 61 / 1327 | 시간 29[s] | 퍼플렉서티 937.63
# | 에폭 1 |  반복 81 / 1327 | 시간 39[s] | 퍼플렉서티 795.93
# | 에폭 1 |  반복 101 / 1327 | 시간 49[s] | 퍼플렉서티 629.84
# | 에폭 1 |  반복 121 / 1327 | 시간 60[s] | 퍼플렉서티 637.23
# | 에폭 1 |  반복 141 / 1327 | 시간 71[s] | 퍼플렉서티 611.65
# | 에폭 1 |  반복 161 / 1327 | 시간 82[s] | 퍼플렉서티 583.04
# | 에폭 1 |  반복 181 / 1327 | 시간 93[s] | 퍼플렉서티 585.86
# | 에폭 1 |  반복 201 / 1327 | 시간 103[s] | 퍼플렉서티 500.65
# | 에폭 1 |  반복 221 / 1327 | 시간 115[s] | 퍼플렉서티 492.91
# | 에폭 1 |  반복 241 / 1327 | 시간 123[s] | 퍼플렉서티 437.17
# | 에폭 1 |  반복 261 / 1327 | 시간 133[s] | 퍼플렉서티 452.74
# | 에폭 1 |  반복 281 / 1327 | 시간 143[s] | 퍼플렉서티 438.09
# | 에폭 1 |  반복 301 / 1327 | 시간 153[s] | 퍼플렉서티 387.28
# | 에폭 1 |  반복 321 / 1327 | 시간 163[s] | 퍼플렉서티 339.65
# | 에폭 1 |  반복 341 / 1327 | 시간 172[s] | 퍼플렉서티 399.16
# | 에폭 1 |  반복 361 / 1327 | 시간 180[s] | 퍼플렉서티 398.06
# | 에폭 1 |  반복 381 / 1327 | 시간 190[s] | 퍼플렉서티 335.11
# | 에폭 1 |  반복 401 / 1327 | 시간 202[s] | 퍼플렉서티 350.14
# | 에폭 1 |  반복 421 / 1327 | 시간 213[s] | 퍼플렉서티 339.82
# | 에폭 1 |  반복 441 / 1327 | 시간 224[s] | 퍼플렉서티 331.22
# | 에폭 1 |  반복 461 / 1327 | 시간 232[s] | 퍼플렉서티 322.56
# | 에폭 1 |  반복 481 / 1327 | 시간 241[s] | 퍼플렉서티 298.96
# | 에폭 1 |  반복 501 / 1327 | 시간 251[s] | 퍼플렉서티 302.86
# | 에폭 1 |  반복 521 / 1327 | 시간 263[s] | 퍼플렉서티 302.86
# | 에폭 1 |  반복 541 / 1327 | 시간 273[s] | 퍼플렉서티 314.82
# | 에폭 1 |  반복 561 / 1327 | 시간 281[s] | 퍼플렉서티 283.58
# | 에폭 1 |  반복 581 / 1327 | 시간 294[s] | 퍼플렉서티 255.85
# | 에폭 1 |  반복 601 / 1327 | 시간 306[s] | 퍼플렉서티 332.15
# | 에폭 1 |  반복 621 / 1327 | 시간 318[s] | 퍼플렉서티 311.34
# | 에폭 1 |  반복 641 / 1327 | 시간 326[s] | 퍼플렉서티 280.29
# | 에폭 1 |  반복 661 / 1327 | 시간 332[s] | 퍼플렉서티 267.95
# | 에폭 1 |  반복 681 / 1327 | 시간 338[s] | 퍼플렉서티 224.18
# | 에폭 1 |  반복 701 / 1327 | 시간 344[s] | 퍼플렉서티 247.49
# | 에폭 1 |  반복 721 / 1327 | 시간 351[s] | 퍼플렉서티 260.67
# | 에폭 1 |  반복 741 / 1327 | 시간 357[s] | 퍼플렉서티 220.02
# | 에폭 1 |  반복 761 / 1327 | 시간 364[s] | 퍼플렉서티 231.76
# | 에폭 1 |  반복 781 / 1327 | 시간 370[s] | 퍼플렉서티 217.22
# | 에폭 1 |  반복 801 / 1327 | 시간 376[s] | 퍼플렉서티 239.99
# | 에폭 1 |  반복 821 / 1327 | 시간 382[s] | 퍼플렉서티 225.52
# | 에폭 1 |  반복 841 / 1327 | 시간 388[s] | 퍼플렉서티 226.15
# | 에폭 1 |  반복 861 / 1327 | 시간 394[s] | 퍼플렉서티 221.90
# | 에폭 1 |  반복 881 / 1327 | 시간 400[s] | 퍼플렉서티 204.46
# | 에폭 1 |  반복 901 / 1327 | 시간 405[s] | 퍼플렉서티 255.54
# | 에폭 1 |  반복 921 / 1327 | 시간 412[s] | 퍼플렉서티 224.73
# | 에폭 1 |  반복 941 / 1327 | 시간 418[s] | 퍼플렉서티 228.08
# | 에폭 1 |  반복 961 / 1327 | 시간 425[s] | 퍼플렉서티 242.03
# | 에폭 1 |  반복 981 / 1327 | 시간 431[s] | 퍼플렉서티 227.84
# | 에폭 1 |  반복 1001 / 1327 | 시간 437[s] | 퍼플렉서티 192.72
# | 에폭 1 |  반복 1021 / 1327 | 시간 443[s] | 퍼플렉서티 225.62
# | 에폭 1 |  반복 1041 / 1327 | 시간 448[s] | 퍼플렉서티 207.11
# | 에폭 1 |  반복 1061 / 1327 | 시간 454[s] | 퍼플렉서티 196.11
# | 에폭 1 |  반복 1081 / 1327 | 시간 460[s] | 퍼플렉서티 166.78
# | 에폭 1 |  반복 1101 / 1327 | 시간 466[s] | 퍼플렉서티 189.18
# | 에폭 1 |  반복 1121 / 1327 | 시간 472[s] | 퍼플렉서티 227.63
# | 에폭 1 |  반복 1141 / 1327 | 시간 479[s] | 퍼플렉서티 207.39
# | 에폭 1 |  반복 1161 / 1327 | 시간 485[s] | 퍼플렉서티 197.59
# | 에폭 1 |  반복 1181 / 1327 | 시간 492[s] | 퍼플렉서티 190.15
# | 에폭 1 |  반복 1201 / 1327 | 시간 498[s] | 퍼플렉서티 162.07
# | 에폭 1 |  반복 1221 / 1327 | 시간 503[s] | 퍼플렉서티 158.07
# | 에폭 1 |  반복 1241 / 1327 | 시간 510[s] | 퍼플렉서티 187.08
# | 에폭 1 |  반복 1261 / 1327 | 시간 516[s] | 퍼플렉서티 171.26
# | 에폭 1 |  반복 1281 / 1327 | 시간 522[s] | 퍼플렉서티 178.47
# | 에폭 1 |  반복 1301 / 1327 | 시간 528[s] | 퍼플렉서티 221.17
# | 에폭 1 |  반복 1321 / 1327 | 시간 534[s] | 퍼플렉서티 209.89
# | 에폭 2 |  반복 1 / 1327 | 시간 536[s] | 퍼플렉서티 225.46
# | 에폭 2 |  반복 21 / 1327 | 시간 542[s] | 퍼플렉서티 203.05
# | 에폭 2 |  반복 41 / 1327 | 시간 547[s] | 퍼플렉서티 190.33
# | 에폭 2 |  반복 61 / 1327 | 시간 553[s] | 퍼플렉서티 175.56
# | 에폭 2 |  반복 81 / 1327 | 시간 559[s] | 퍼플렉서티 157.61
# | 에폭 2 |  반복 101 / 1327 | 시간 565[s] | 퍼플렉서티 153.92
# | 에폭 2 |  반복 121 / 1327 | 시간 572[s] | 퍼플렉서티 160.05
# | 에폭 2 |  반복 141 / 1327 | 시간 578[s] | 퍼플렉서티 178.22
# | 에폭 2 |  반복 161 / 1327 | 시간 584[s] | 퍼플렉서티 193.39
# | 에폭 2 |  반복 181 / 1327 | 시간 589[s] | 퍼플렉서티 200.70
# | 에폭 2 |  반복 201 / 1327 | 시간 595[s] | 퍼플렉서티 185.98
# | 에폭 2 |  반복 221 / 1327 | 시간 601[s] | 퍼플렉서티 183.56
# | 에폭 2 |  반복 241 / 1327 | 시간 607[s] | 퍼플렉서티 174.38
# | 에폭 2 |  반복 261 / 1327 | 시간 614[s] | 퍼플렉서티 184.79
# | 에폭 2 |  반복 281 / 1327 | 시간 620[s] | 퍼플렉서티 188.09
# | 에폭 2 |  반복 301 / 1327 | 시간 626[s] | 퍼플렉서티 167.16
# | 에폭 2 |  반복 321 / 1327 | 시간 632[s] | 퍼플렉서티 137.46
# | 에폭 2 |  반복 341 / 1327 | 시간 639[s] | 퍼플렉서티 172.23
# | 에폭 2 |  반복 361 / 1327 | 시간 646[s] | 퍼플렉서티 196.05
# | 에폭 2 |  반복 381 / 1327 | 시간 652[s] | 퍼플렉서티 152.71
# | 에폭 2 |  반복 401 / 1327 | 시간 660[s] | 퍼플렉서티 169.19
# | 에폭 2 |  반복 421 / 1327 | 시간 665[s] | 퍼플렉서티 155.13
# | 에폭 2 |  반복 441 / 1327 | 시간 672[s] | 퍼플렉서티 162.86
# | 에폭 2 |  반복 461 / 1327 | 시간 678[s] | 퍼플렉서티 157.85
# | 에폭 2 |  반복 481 / 1327 | 시간 684[s] | 퍼플렉서티 156.31
# | 에폭 2 |  반복 501 / 1327 | 시간 690[s] | 퍼플렉서티 168.90
# | 에폭 2 |  반복 521 / 1327 | 시간 696[s] | 퍼플렉서티 173.01
# | 에폭 2 |  반복 541 / 1327 | 시간 704[s] | 퍼플렉서티 175.62
# | 에폭 2 |  반복 561 / 1327 | 시간 710[s] | 퍼플렉서티 155.37
# | 에폭 2 |  반복 581 / 1327 | 시간 717[s] | 퍼플렉서티 138.61
# | 에폭 2 |  반복 601 / 1327 | 시간 723[s] | 퍼플렉서티 191.34
# | 에폭 2 |  반복 621 / 1327 | 시간 728[s] | 퍼플렉서티 180.44
# | 에폭 2 |  반복 641 / 1327 | 시간 735[s] | 퍼플렉서티 163.84
# | 에폭 2 |  반복 661 / 1327 | 시간 740[s] | 퍼플렉서티 153.22
# | 에폭 2 |  반복 681 / 1327 | 시간 747[s] | 퍼플렉서티 131.01
# | 에폭 2 |  반복 701 / 1327 | 시간 753[s] | 퍼플렉서티 150.72
# | 에폭 2 |  반복 721 / 1327 | 시간 759[s] | 퍼플렉서티 160.60
# | 에폭 2 |  반복 741 / 1327 | 시간 765[s] | 퍼플렉서티 134.31
# | 에폭 2 |  반복 761 / 1327 | 시간 772[s] | 퍼플렉서티 132.03
# | 에폭 2 |  반복 781 / 1327 | 시간 778[s] | 퍼플렉서티 137.14
# | 에폭 2 |  반복 801 / 1327 | 시간 784[s] | 퍼플렉서티 147.18
# | 에폭 2 |  반복 821 / 1327 | 시간 790[s] | 퍼플렉서티 143.00
# | 에폭 2 |  반복 841 / 1327 | 시간 795[s] | 퍼플렉서티 144.17
# | 에폭 2 |  반복 861 / 1327 | 시간 801[s] | 퍼플렉서티 145.74
# | 에폭 2 |  반복 881 / 1327 | 시간 807[s] | 퍼플렉서티 129.64
# | 에폭 2 |  반복 901 / 1327 | 시간 814[s] | 퍼플렉서티 166.24
# | 에폭 2 |  반복 921 / 1327 | 시간 820[s] | 퍼플렉서티 147.46
# | 에폭 2 |  반복 941 / 1327 | 시간 827[s] | 퍼플렉서티 154.28
# | 에폭 2 |  반복 961 / 1327 | 시간 833[s] | 퍼플렉서티 163.98
# | 에폭 2 |  반복 981 / 1327 | 시간 839[s] | 퍼플렉서티 155.40
# | 에폭 2 |  반복 1001 / 1327 | 시간 844[s] | 퍼플렉서티 132.13
# | 에폭 2 |  반복 1021 / 1327 | 시간 850[s] | 퍼플렉서티 156.18
# | 에폭 2 |  반복 1041 / 1327 | 시간 856[s] | 퍼플렉서티 143.23
# | 에폭 2 |  반복 1061 / 1327 | 시간 862[s] | 퍼플렉서티 128.58
# | 에폭 2 |  반복 1081 / 1327 | 시간 868[s] | 퍼플렉서티 111.74
# | 에폭 2 |  반복 1101 / 1327 | 시간 874[s] | 퍼플렉서티 118.64
# | 에폭 2 |  반복 1121 / 1327 | 시간 880[s] | 퍼플렉서티 153.98
# | 에폭 2 |  반복 1141 / 1327 | 시간 886[s] | 퍼플렉서티 142.62
# | 에폭 2 |  반복 1161 / 1327 | 시간 892[s] | 퍼플렉서티 133.88
# | 에폭 2 |  반복 1181 / 1327 | 시간 898[s] | 퍼플렉서티 134.92
# | 에폭 2 |  반복 1201 / 1327 | 시간 904[s] | 퍼플렉서티 113.38
# | 에폭 2 |  반복 1221 / 1327 | 시간 910[s] | 퍼플렉서티 108.79
# | 에폭 2 |  반복 1241 / 1327 | 시간 916[s] | 퍼플렉서티 130.24
# | 에폭 2 |  반복 1261 / 1327 | 시간 921[s] | 퍼플렉서티 124.45
# | 에폭 2 |  반복 1281 / 1327 | 시간 927[s] | 퍼플렉서티 123.32
# | 에폭 2 |  반복 1301 / 1327 | 시간 933[s] | 퍼플렉서티 157.29
# | 에폭 2 |  반복 1321 / 1327 | 시간 940[s] | 퍼플렉서티 154.07
# | 에폭 3 |  반복 1 / 1327 | 시간 942[s] | 퍼플렉서티 163.47
# | 에폭 3 |  반복 21 / 1327 | 시간 948[s] | 퍼플렉서티 143.84
# | 에폭 3 |  반복 41 / 1327 | 시간 954[s] | 퍼플렉서티 136.27
# | 에폭 3 |  반복 61 / 1327 | 시간 960[s] | 퍼플렉서티 128.30
# | 에폭 3 |  반복 81 / 1327 | 시간 966[s] | 퍼플렉서티 116.88
# | 에폭 3 |  반복 101 / 1327 | 시간 972[s] | 퍼플렉서티 107.43
# | 에폭 3 |  반복 121 / 1327 | 시간 977[s] | 퍼플렉서티 115.79
# | 에폭 3 |  반복 141 / 1327 | 시간 983[s] | 퍼플렉서티 126.63
# | 에폭 3 |  반복 161 / 1327 | 시간 990[s] | 퍼플렉서티 143.18
# | 에폭 3 |  반복 181 / 1327 | 시간 996[s] | 퍼플렉서티 152.20
# | 에폭 3 |  반복 201 / 1327 | 시간 1002[s] | 퍼플렉서티 143.06
# | 에폭 3 |  반복 221 / 1327 | 시간 1008[s] | 퍼플렉서티 141.53
# | 에폭 3 |  반복 241 / 1327 | 시간 1013[s] | 퍼플렉서티 133.31
# | 에폭 3 |  반복 261 / 1327 | 시간 1019[s] | 퍼플렉서티 139.38
# | 에폭 3 |  반복 281 / 1327 | 시간 1025[s] | 퍼플렉서티 143.12
# | 에폭 3 |  반복 301 / 1327 | 시간 1031[s] | 퍼플렉서티 126.12
# | 에폭 3 |  반복 321 / 1327 | 시간 1038[s] | 퍼플렉서티 102.53
# | 에폭 3 |  반복 341 / 1327 | 시간 1044[s] | 퍼플렉서티 126.18
# | 에폭 3 |  반복 361 / 1327 | 시간 1050[s] | 퍼플렉서티 152.34
# | 에폭 3 |  반복 381 / 1327 | 시간 1056[s] | 퍼플렉서티 114.44
# | 에폭 3 |  반복 401 / 1327 | 시간 1061[s] | 퍼플렉서티 129.72
# | 에폭 3 |  반복 421 / 1327 | 시간 1068[s] | 퍼플렉서티 114.40
# | 에폭 3 |  반복 441 / 1327 | 시간 1074[s] | 퍼플렉서티 124.06
# | 에폭 3 |  반복 461 / 1327 | 시간 1080[s] | 퍼플렉서티 119.04
# | 에폭 3 |  반복 481 / 1327 | 시간 1086[s] | 퍼플렉서티 119.20
# | 에폭 3 |  반복 501 / 1327 | 시간 1091[s] | 퍼플렉서티 128.92
# | 에폭 3 |  반복 521 / 1327 | 시간 1097[s] | 퍼플렉서티 138.47
# | 에폭 3 |  반복 541 / 1327 | 시간 1103[s] | 퍼플렉서티 137.25
# | 에폭 3 |  반복 561 / 1327 | 시간 1109[s] | 퍼플렉서티 119.72
# | 에폭 3 |  반복 581 / 1327 | 시간 1116[s] | 퍼플렉서티 106.89
# | 에폭 3 |  반복 601 / 1327 | 시간 1122[s] | 퍼플렉서티 148.81
# | 에폭 3 |  반복 621 / 1327 | 시간 1127[s] | 퍼플렉서티 143.81
# | 에폭 3 |  반복 641 / 1327 | 시간 1134[s] | 퍼플렉서티 128.00
# | 에폭 3 |  반복 661 / 1327 | 시간 1140[s] | 퍼플렉서티 119.37
# | 에폭 3 |  반복 681 / 1327 | 시간 1146[s] | 퍼플렉서티 100.32
# | 에폭 3 |  반복 701 / 1327 | 시간 1152[s] | 퍼플렉서티 119.00
# | 에폭 3 |  반복 721 / 1327 | 시간 1157[s] | 퍼플렉서티 126.03
# | 에폭 3 |  반복 741 / 1327 | 시간 1163[s] | 퍼플렉서티 109.47
# | 에폭 3 |  반복 761 / 1327 | 시간 1169[s] | 퍼플렉서티 104.18
# | 에폭 3 |  반복 781 / 1327 | 시간 1175[s] | 퍼플렉서티 105.48
# | 에폭 3 |  반복 801 / 1327 | 시간 1181[s] | 퍼플렉서티 116.38
# | 에폭 3 |  반복 821 / 1327 | 시간 1187[s] | 퍼플렉서티 116.78
# | 에폭 3 |  반복 841 / 1327 | 시간 1193[s] | 퍼플렉서티 114.46
# | 에폭 3 |  반복 861 / 1327 | 시간 1200[s] | 퍼플렉서티 121.33
# | 에폭 3 |  반복 881 / 1327 | 시간 1205[s] | 퍼플렉서티 106.03
# | 에폭 3 |  반복 901 / 1327 | 시간 1211[s] | 퍼플렉서티 132.90
# | 에폭 3 |  반복 921 / 1327 | 시간 1217[s] | 퍼플렉서티 120.24
# | 에폭 3 |  반복 941 / 1327 | 시간 1223[s] | 퍼플렉서티 129.22
# | 에폭 3 |  반복 961 / 1327 | 시간 1229[s] | 퍼플렉서티 132.84
# | 에폭 3 |  반복 981 / 1327 | 시간 1236[s] | 퍼플렉서티 125.07
# | 에폭 3 |  반복 1001 / 1327 | 시간 1242[s] | 퍼플렉서티 109.43
# | 에폭 3 |  반복 1021 / 1327 | 시간 1247[s] | 퍼플렉서티 128.32
# | 에폭 3 |  반복 1041 / 1327 | 시간 1253[s] | 퍼플렉서티 119.38
# | 에폭 3 |  반복 1061 / 1327 | 시간 1260[s] | 퍼플렉서티 103.39
# | 에폭 3 |  반복 1081 / 1327 | 시간 1265[s] | 퍼플렉서티 88.69
# | 에폭 3 |  반복 1101 / 1327 | 시간 1271[s] | 퍼플렉서티 94.62
# | 에폭 3 |  반복 1121 / 1327 | 시간 1277[s] | 퍼플렉서티 121.16
# | 에폭 3 |  반복 1141 / 1327 | 시간 1284[s] | 퍼플렉서티 114.66
# | 에폭 3 |  반복 1161 / 1327 | 시간 1290[s] | 퍼플렉서티 106.99
# | 에폭 3 |  반복 1181 / 1327 | 시간 1296[s] | 퍼플렉서티 112.35
# | 에폭 3 |  반복 1201 / 1327 | 시간 1301[s] | 퍼플렉서티 94.73
# | 에폭 3 |  반복 1221 / 1327 | 시간 1308[s] | 퍼플렉서티 88.44
# | 에폭 3 |  반복 1241 / 1327 | 시간 1317[s] | 퍼플렉서티 104.95
# | 에폭 3 |  반복 1261 / 1327 | 시간 1326[s] | 퍼플렉서티 105.96
# | 에폭 3 |  반복 1281 / 1327 | 시간 1332[s] | 퍼플렉서티 101.71
# | 에폭 3 |  반복 1301 / 1327 | 시간 1338[s] | 퍼플렉서티 130.08
# | 에폭 3 |  반복 1321 / 1327 | 시간 1344[s] | 퍼플렉서티 127.92
# | 에폭 4 |  반복 1 / 1327 | 시간 1346[s] | 퍼플렉서티 134.03
# | 에폭 4 |  반복 21 / 1327 | 시간 1352[s] | 퍼플렉서티 122.67
# | 에폭 4 |  반복 41 / 1327 | 시간 1359[s] | 퍼플렉서티 107.51
# | 에폭 4 |  반복 61 / 1327 | 시간 1366[s] | 퍼플렉서티 108.82
# | 에폭 4 |  반복 81 / 1327 | 시간 1373[s] | 퍼플렉서티 95.55
# | 에폭 4 |  반복 101 / 1327 | 시간 1379[s] | 퍼플렉서티 87.94
# | 에폭 4 |  반복 121 / 1327 | 시간 1386[s] | 퍼플렉서티 96.10
