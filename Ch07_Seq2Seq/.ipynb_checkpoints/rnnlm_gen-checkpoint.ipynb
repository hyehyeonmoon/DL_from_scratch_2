# %%
# coding: utf-8
import sys
sys.path.append('..')
import numpy as np
from common.functions import softmax
from Ch07_Seq2Seq.rnnlm import Rnnlm
from Ch07_Seq2Seq.better_rnnlm import BetterRnnlm


class RnnlmGen(Rnnlm):
    def generate(self, start_id, skip_ids=None, sample_size=100):
        word_ids = [start_id]

        x = start_id
        while len(word_ids) < sample_size:
            x = np.array(x).reshape(1, 1)
            score = self.predict(x)
            p = softmax(score.flatten())

            sampled = np.random.choice(len(p), size=1, p=p)
            if (skip_ids is None) or (sampled not in skip_ids):
                x = sampled
                word_ids.append(int(x))

        return word_ids

    def get_state(self):
        return self.lstm_layer.h, self.lstm_layer.c

    def set_state(self, state):
        self.lstm_layer.set_state(*state)


class BetterRnnlmGen(BetterRnnlm):
    def generate(self, start_id, skip_ids=None, sample_size=100):
        word_ids = [start_id]

        x = start_id
        while len(word_ids) < sample_size:
            x = np.array(x).reshape(1, 1)
            score = self.predict(x).flatten()
            p = softmax(score).flatten()

            sampled = np.random.choice(len(p), size=1, p=p)
            if (skip_ids is None) or (sampled not in skip_ids):
                x = sampled
                word_ids.append(int(x))

        return word_ids

    def get_state(self):
        states = []
        for layer in self.lstm_layers:
            states.append((layer.h, layer.c))
        return states

    def set_state(self, states):
        for layer, state in zip(self.lstm_layers, states):
            layer.set_state(*state)
# Out:
# | 에폭 1 |  반복 1 / 1327 | 시간 0[s] | 퍼플렉서티 9996.03
# | 에폭 1 |  반복 21 / 1327 | 시간 11[s] | 퍼플렉서티 2945.71
# | 에폭 1 |  반복 41 / 1327 | 시간 19[s] | 퍼플렉서티 1248.50
# | 에폭 1 |  반복 61 / 1327 | 시간 27[s] | 퍼플렉서티 995.24
# | 에폭 1 |  반복 81 / 1327 | 시간 37[s] | 퍼플렉서티 793.66
# | 에폭 1 |  반복 101 / 1327 | 시간 46[s] | 퍼플렉서티 652.22
# | 에폭 1 |  반복 121 / 1327 | 시간 57[s] | 퍼플렉서티 652.59
# | 에폭 1 |  반복 141 / 1327 | 시간 67[s] | 퍼플렉서티 595.10
# | 에폭 1 |  반복 161 / 1327 | 시간 78[s] | 퍼플렉서티 583.60
# | 에폭 1 |  반복 181 / 1327 | 시간 88[s] | 퍼플렉서티 569.80
# | 에폭 1 |  반복 201 / 1327 | 시간 98[s] | 퍼플렉서티 498.25
# | 에폭 1 |  반복 221 / 1327 | 시간 110[s] | 퍼플렉서티 486.08
# | 에폭 1 |  반복 241 / 1327 | 시간 121[s] | 퍼플렉서티 437.35
# | 에폭 1 |  반복 261 / 1327 | 시간 132[s] | 퍼플렉서티 453.39
# | 에폭 1 |  반복 281 / 1327 | 시간 142[s] | 퍼플렉서티 451.88
# | 에폭 1 |  반복 301 / 1327 | 시간 151[s] | 퍼플렉서티 385.76
# | 에폭 1 |  반복 321 / 1327 | 시간 160[s] | 퍼플렉서티 347.42
# | 에폭 1 |  반복 341 / 1327 | 시간 170[s] | 퍼플렉서티 400.28
# | 에폭 1 |  반복 361 / 1327 | 시간 181[s] | 퍼플렉서티 398.43
# | 에폭 1 |  반복 381 / 1327 | 시간 191[s] | 퍼플렉서티 333.08
# | 에폭 1 |  반복 401 / 1327 | 시간 199[s] | 퍼플렉서티 348.07
# | 에폭 1 |  반복 421 / 1327 | 시간 208[s] | 퍼플렉서티 338.68
# | 에폭 1 |  반복 441 / 1327 | 시간 220[s] | 퍼플렉서티 329.85
# | 에폭 1 |  반복 461 / 1327 | 시간 230[s] | 퍼플렉서티 325.33
# | 에폭 1 |  반복 481 / 1327 | 시간 241[s] | 퍼플렉서티 303.09
# | 에폭 1 |  반복 501 / 1327 | 시간 251[s] | 퍼플렉서티 303.65
# | 에폭 1 |  반복 521 / 1327 | 시간 260[s] | 퍼플렉서티 302.18
# | 에폭 1 |  반복 541 / 1327 | 시간 269[s] | 퍼플렉서티 318.11
# | 에폭 1 |  반복 561 / 1327 | 시간 279[s] | 퍼플렉서티 287.45
# | 에폭 1 |  반복 581 / 1327 | 시간 292[s] | 퍼플렉서티 259.36
# | 에폭 1 |  반복 601 / 1327 | 시간 300[s] | 퍼플렉서티 337.16
# | 에폭 1 |  반복 621 / 1327 | 시간 311[s] | 퍼플렉서티 308.97
# | 에폭 1 |  반복 641 / 1327 | 시간 323[s] | 퍼플렉서티 281.25
# | 에폭 1 |  반복 661 / 1327 | 시간 334[s] | 퍼플렉서티 269.02
