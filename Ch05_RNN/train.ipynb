# %%
# coding: utf-8
import sys
sys.path.append('..')
from common.optimizer import SGD
from common.trainer import RnnlmTrainer
from dataset import ptb
from simple_rnnlm import SimpleRnnlm


# 하이퍼파라미터 설정
batch_size = 10
wordvec_size = 100
hidden_size = 100  # RNN의 은닉 상태 벡터의 원소 수
time_size = 5  # RNN을 펼치는 크기
lr = 0.1
max_epoch = 100

# 학습 데이터 읽기
corpus, word_to_id, id_to_word = ptb.load_data('train')
corpus_size = 1000  # 테스트 데이터셋을 작게 설정
corpus = corpus[:corpus_size]
vocab_size = int(max(corpus) + 1)
xs = corpus[:-1]  # 입력
ts = corpus[1:]  # 출력（정답 레이블）

# 모델 생성
model = SimpleRnnlm(vocab_size, wordvec_size, hidden_size)
optimizer = SGD(lr)
trainer = RnnlmTrainer(model, optimizer)

trainer.fit(xs, ts, max_epoch, batch_size, time_size)
trainer.plot()
# Out:
# | 에폭 1 |  반복 1 / 19 | 시간 0[s] | 퍼플렉서티 419.09
# | 에폭 2 |  반복 1 / 19 | 시간 0[s] | 퍼플렉서티 374.38
# | 에폭 3 |  반복 1 / 19 | 시간 0[s] | 퍼플렉서티 270.20
# | 에폭 4 |  반복 1 / 19 | 시간 0[s] | 퍼플렉서티 229.07
# | 에폭 5 |  반복 1 / 19 | 시간 0[s] | 퍼플렉서티 214.51
# | 에폭 6 |  반복 1 / 19 | 시간 0[s] | 퍼플렉서티 212.02
# | 에폭 7 |  반복 1 / 19 | 시간 0[s] | 퍼플렉서티 203.48
# | 에폭 8 |  반복 1 / 19 | 시간 0[s] | 퍼플렉서티 199.92
# | 에폭 9 |  반복 1 / 19 | 시간 1[s] | 퍼플렉서티 195.15
# | 에폭 10 |  반복 1 / 19 | 시간 1[s] | 퍼플렉서티 189.77
# | 에폭 11 |  반복 1 / 19 | 시간 1[s] | 퍼플렉서티 190.83
# | 에폭 12 |  반복 1 / 19 | 시간 1[s] | 퍼플렉서티 187.32
# | 에폭 13 |  반복 1 / 19 | 시간 1[s] | 퍼플렉서티 192.14
# | 에폭 14 |  반복 1 / 19 | 시간 1[s] | 퍼플렉서티 185.77
# | 에폭 15 |  반복 1 / 19 | 시간 2[s] | 퍼플렉서티 182.97
# | 에폭 16 |  반복 1 / 19 | 시간 2[s] | 퍼플렉서티 188.68
# | 에폭 17 |  반복 1 / 19 | 시간 2[s] | 퍼플렉서티 187.50
# | 에폭 18 |  반복 1 / 19 | 시간 2[s] | 퍼플렉서티 184.04
# | 에폭 19 |  반복 1 / 19 | 시간 2[s] | 퍼플렉서티 177.13
# | 에폭 20 |  반복 1 / 19 | 시간 2[s] | 퍼플렉서티 179.15
# | 에폭 21 |  반복 1 / 19 | 시간 2[s] | 퍼플렉서티 175.45
# | 에폭 22 |  반복 1 / 19 | 시간 3[s] | 퍼플렉서티 171.35
# | 에폭 23 |  반복 1 / 19 | 시간 3[s] | 퍼플렉서티 178.48
# | 에폭 24 |  반복 1 / 19 | 시간 3[s] | 퍼플렉서티 172.26
# | 에폭 25 |  반복 1 / 19 | 시간 3[s] | 퍼플렉서티 166.35
# | 에폭 26 |  반복 1 / 19 | 시간 3[s] | 퍼플렉서티 168.19
# | 에폭 27 |  반복 1 / 19 | 시간 3[s] | 퍼플렉서티 164.05
# | 에폭 28 |  반복 1 / 19 | 시간 3[s] | 퍼플렉서티 162.90
# | 에폭 29 |  반복 1 / 19 | 시간 4[s] | 퍼플렉서티 159.48
# | 에폭 30 |  반복 1 / 19 | 시간 4[s] | 퍼플렉서티 155.43
# | 에폭 31 |  반복 1 / 19 | 시간 4[s] | 퍼플렉서티 150.93
# | 에폭 32 |  반복 1 / 19 | 시간 4[s] | 퍼플렉서티 146.32
# | 에폭 33 |  반복 1 / 19 | 시간 4[s] | 퍼플렉서티 147.74
# | 에폭 34 |  반복 1 / 19 | 시간 4[s] | 퍼플렉서티 144.29
# | 에폭 35 |  반복 1 / 19 | 시간 5[s] | 퍼플렉서티 135.73
# | 에폭 36 |  반복 1 / 19 | 시간 5[s] | 퍼플렉서티 134.03
# | 에폭 37 |  반복 1 / 19 | 시간 5[s] | 퍼플렉서티 134.19
# | 에폭 38 |  반복 1 / 19 | 시간 5[s] | 퍼플렉서티 125.03
# | 에폭 39 |  반복 1 / 19 | 시간 5[s] | 퍼플렉서티 122.55
# | 에폭 40 |  반복 1 / 19 | 시간 5[s] | 퍼플렉서티 118.28
# | 에폭 41 |  반복 1 / 19 | 시간 5[s] | 퍼플렉서티 110.69
# | 에폭 42 |  반복 1 / 19 | 시간 6[s] | 퍼플렉서티 108.93
# | 에폭 43 |  반복 1 / 19 | 시간 6[s] | 퍼플렉서티 104.46
# | 에폭 44 |  반복 1 / 19 | 시간 6[s] | 퍼플렉서티 103.58
# | 에폭 45 |  반복 1 / 19 | 시간 6[s] | 퍼플렉서티 96.11
# | 에폭 46 |  반복 1 / 19 | 시간 6[s] | 퍼플렉서티 91.12
# | 에폭 47 |  반복 1 / 19 | 시간 6[s] | 퍼플렉서티 88.51
# | 에폭 48 |  반복 1 / 19 | 시간 6[s] | 퍼플렉서티 86.43
# | 에폭 49 |  반복 1 / 19 | 시간 6[s] | 퍼플렉서티 80.76
# | 에폭 50 |  반복 1 / 19 | 시간 7[s] | 퍼플렉서티 76.05
# | 에폭 51 |  반복 1 / 19 | 시간 7[s] | 퍼플렉서티 73.12
# | 에폭 52 |  반복 1 / 19 | 시간 7[s] | 퍼플렉서티 68.31
# | 에폭 53 |  반복 1 / 19 | 시간 7[s] | 퍼플렉서티 66.08
# | 에폭 54 |  반복 1 / 19 | 시간 7[s] | 퍼플렉서티 62.28
# | 에폭 55 |  반복 1 / 19 | 시간 7[s] | 퍼플렉서티 60.23
# | 에폭 56 |  반복 1 / 19 | 시간 7[s] | 퍼플렉서티 56.28
# | 에폭 57 |  반복 1 / 19 | 시간 7[s] | 퍼플렉서티 53.87
# | 에폭 58 |  반복 1 / 19 | 시간 7[s] | 퍼플렉서티 50.21
# | 에폭 59 |  반복 1 / 19 | 시간 8[s] | 퍼플렉서티 48.28
# | 에폭 60 |  반복 1 / 19 | 시간 8[s] | 퍼플렉서티 45.14
# | 에폭 61 |  반복 1 / 19 | 시간 8[s] | 퍼플렉서티 41.05
# | 에폭 62 |  반복 1 / 19 | 시간 8[s] | 퍼플렉서티 39.73
# | 에폭 63 |  반복 1 / 19 | 시간 8[s] | 퍼플렉서티 38.04
# | 에폭 64 |  반복 1 / 19 | 시간 8[s] | 퍼플렉서티 36.09
# | 에폭 65 |  반복 1 / 19 | 시간 9[s] | 퍼플렉서티 33.97
# | 에폭 66 |  반복 1 / 19 | 시간 9[s] | 퍼플렉서티 31.63
# | 에폭 67 |  반복 1 / 19 | 시간 9[s] | 퍼플렉서티 30.47
# | 에폭 68 |  반복 1 / 19 | 시간 9[s] | 퍼플렉서티 28.91
# | 에폭 69 |  반복 1 / 19 | 시간 9[s] | 퍼플렉서티 27.17
# | 에폭 70 |  반복 1 / 19 | 시간 9[s] | 퍼플렉서티 25.25
# | 에폭 71 |  반복 1 / 19 | 시간 9[s] | 퍼플렉서티 23.62
# | 에폭 72 |  반복 1 / 19 | 시간 9[s] | 퍼플렉서티 21.79
# | 에폭 73 |  반복 1 / 19 | 시간 9[s] | 퍼플렉서티 21.30
# | 에폭 74 |  반복 1 / 19 | 시간 10[s] | 퍼플렉서티 20.20
# | 에폭 75 |  반복 1 / 19 | 시간 10[s] | 퍼플렉서티 18.85
# | 에폭 76 |  반복 1 / 19 | 시간 10[s] | 퍼플렉서티 17.98
# | 에폭 77 |  반복 1 / 19 | 시간 10[s] | 퍼플렉서티 17.46
# | 에폭 78 |  반복 1 / 19 | 시간 10[s] | 퍼플렉서티 16.13
# | 에폭 79 |  반복 1 / 19 | 시간 11[s] | 퍼플렉서티 15.15
# | 에폭 80 |  반복 1 / 19 | 시간 11[s] | 퍼플렉서티 14.26
# | 에폭 81 |  반복 1 / 19 | 시간 11[s] | 퍼플렉서티 13.31
# | 에폭 82 |  반복 1 / 19 | 시간 11[s] | 퍼플렉서티 12.52
# | 에폭 83 |  반복 1 / 19 | 시간 11[s] | 퍼플렉서티 12.48
# | 에폭 84 |  반복 1 / 19 | 시간 11[s] | 퍼플렉서티 11.50
# | 에폭 85 |  반복 1 / 19 | 시간 12[s] | 퍼플렉서티 10.81
# | 에폭 86 |  반복 1 / 19 | 시간 12[s] | 퍼플렉서티 10.28
# | 에폭 87 |  반복 1 / 19 | 시간 12[s] | 퍼플렉서티 9.66
# | 에폭 88 |  반복 1 / 19 | 시간 12[s] | 퍼플렉서티 9.58
# | 에폭 89 |  반복 1 / 19 | 시간 12[s] | 퍼플렉서티 9.23
# | 에폭 90 |  반복 1 / 19 | 시간 12[s] | 퍼플렉서티 8.43
# | 에폭 91 |  반복 1 / 19 | 시간 13[s] | 퍼플렉서티 8.14
# | 에폭 92 |  반복 1 / 19 | 시간 13[s] | 퍼플렉서티 7.55
# | 에폭 93 |  반복 1 / 19 | 시간 13[s] | 퍼플렉서티 7.34
# | 에폭 94 |  반복 1 / 19 | 시간 13[s] | 퍼플렉서티 6.78
# | 에폭 95 |  반복 1 / 19 | 시간 13[s] | 퍼플렉서티 6.59
# | 에폭 96 |  반복 1 / 19 | 시간 13[s] | 퍼플렉서티 6.44
# | 에폭 97 |  반복 1 / 19 | 시간 13[s] | 퍼플렉서티 6.04
# | 에폭 98 |  반복 1 / 19 | 시간 13[s] | 퍼플렉서티 5.77
# | 에폭 99 |  반복 1 / 19 | 시간 13[s] | 퍼플렉서티 5.33
# | 에폭 100 |  반복 1 / 19 | 시간 14[s] | 퍼플렉서티 5.31
# c:\users\moonf\appdata\local\programs\python\python37\lib\site-packages\matplotlib\backends\backend_agg.py:214: RuntimeWarning: Glyph 48152 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# c:\users\moonf\appdata\local\programs\python\python37\lib\site-packages\matplotlib\backends\backend_agg.py:214: RuntimeWarning: Glyph 48373 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# c:\users\moonf\appdata\local\programs\python\python37\lib\site-packages\matplotlib\backends\backend_agg.py:214: RuntimeWarning: Glyph 54140 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# c:\users\moonf\appdata\local\programs\python\python37\lib\site-packages\matplotlib\backends\backend_agg.py:214: RuntimeWarning: Glyph 54540 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# c:\users\moonf\appdata\local\programs\python\python37\lib\site-packages\matplotlib\backends\backend_agg.py:214: RuntimeWarning: Glyph 47113 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# c:\users\moonf\appdata\local\programs\python\python37\lib\site-packages\matplotlib\backends\backend_agg.py:214: RuntimeWarning: Glyph 49436 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# c:\users\moonf\appdata\local\programs\python\python37\lib\site-packages\matplotlib\backends\backend_agg.py:214: RuntimeWarning: Glyph 54000 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# c:\users\moonf\appdata\local\programs\python\python37\lib\site-packages\matplotlib\backends\backend_agg.py:183: RuntimeWarning: Glyph 48152 missing from current font.
#   font.set_text(s, 0, flags=flags)
# c:\users\moonf\appdata\local\programs\python\python37\lib\site-packages\matplotlib\backends\backend_agg.py:183: RuntimeWarning: Glyph 48373 missing from current font.
#   font.set_text(s, 0, flags=flags)
# c:\users\moonf\appdata\local\programs\python\python37\lib\site-packages\matplotlib\backends\backend_agg.py:183: RuntimeWarning: Glyph 54140 missing from current font.
#   font.set_text(s, 0, flags=flags)
# c:\users\moonf\appdata\local\programs\python\python37\lib\site-packages\matplotlib\backends\backend_agg.py:183: RuntimeWarning: Glyph 54540 missing from current font.
#   font.set_text(s, 0, flags=flags)
# c:\users\moonf\appdata\local\programs\python\python37\lib\site-packages\matplotlib\backends\backend_agg.py:183: RuntimeWarning: Glyph 47113 missing from current font.
#   font.set_text(s, 0, flags=flags)
# c:\users\moonf\appdata\local\programs\python\python37\lib\site-packages\matplotlib\backends\backend_agg.py:183: RuntimeWarning: Glyph 49436 missing from current font.
#   font.set_text(s, 0, flags=flags)
# c:\users\moonf\appdata\local\programs\python\python37\lib\site-packages\matplotlib\backends\backend_agg.py:183: RuntimeWarning: Glyph 54000 missing from current font.
#   font.set_text(s, 0, flags=flags)
